# %%
# !python main.py --device cpu
# Out:
# Torch Device: cpu
# ========= Question 6c =========
# # Samples written to samples.txt.
# ========= Question 6d =========
# # Figure written to random.png.
# # Figure written to shakespeare.png.
# # Figure written to neurips.png.
# ========= Question 6e =========
# # Classification completed.
# ========= Question 6f =========
# # Samples written to samples_temperature0-95.txt.
# ========= Question 6h =========
# # Samples written to samples_temperature0-95_horizon2.txt.
# ...
# 100%|##########| 512/512 [00:52<00:00,  9.84it/s]
#
# ...
# 100%|##########| 512/512 [00:55<00:00,  9.30it/s]
#
# ...
#  52%|#####1    | 265/512 [00:24<00:26,  9.18it/s]
# ...
# ...
# 100%|##########| 512/512 [00:55<00:00,  9.25it/s]
#
# ...
# 100%|##########| 100/100 [08:07<00:00,  4.88s/it]
